# %%
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.layers import Dense, InputLayer
from keras.models import Sequential

from sklearn.model_selection import train_test_split

# %%
data_1 = pd.read_csv('train.csv')

# %%
data_1.head()
# Out:
#   image_names  class
# 0    0001.jpg      1
# 1    0002.jpg      1
# 2    0003.jpg      1
# 3    0004.jpg      1
# 4    0005.jpg      1

# %%
data_2 = pd.read_csv('test.csv')

# %%
data_2.head()
# Out:
#   image_names
# 0    0001.jpg
# 1    0002.jpg
# 2    0003.jpg
# 3    0004.jpg
# 4    0005.jpg

# %%
# create random number generator
seed = 42
rng = np.random.RandomState(seed)

# %%
# distribution of classes in the dataset
data_1['class'].value_counts()
# Out:
# class
# 1    3150
# 0    1449
# Name: count, dtype: int64

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data_1.image_names:
    # loading the image using its name
    img = plt.imread('images/' + img_name)
    # saving each image in the list
    X.append(img)
    
# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data_1['class'].values
#y = data_1.class.values

# %%
X.shape
# Out:
# (4599, 224, 224, 3)

# %%
# visualizing images
fig,ax = plt.subplots(nrows=1,ncols=5,figsize=(20,20))
for i in range(5):
    ax[i].imshow(X[i*450])
    ax[i].axis('off')

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (4599, 150528)

# %%
X.min(), X.max()
# Out:
# (0, 255)

# %%
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((3219, 150528), (3219,)), ((1380, 150528), (1380,)))

# %%
# defining the architecture of the model
model=Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# C:\Users\mcmsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
# summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 100)                 │      15,052,900 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,053,001 (57.42 MB)
#  Trainable params: 15,053,001 (57.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compiling the model
model.compile(loss='binary_crossentropy', optimizer="sgd", metrics=['accuracy'])

# %%
# training the model
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6403 - loss: 0.6772 - val_accuracy: 0.6833 - val_loss: 0.6239
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.6718 - loss: 0.6326 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.6820 - loss: 0.6259 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.7013 - loss: 0.6107 - val_accuracy: 0.6833 - val_loss: 0.6250
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.6744 - loss: 0.6311 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.6860 - loss: 0.6222 - val_accuracy: 0.6833 - val_loss: 0.6253
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.6798 - loss: 0.6283 - val_accuracy: 0.6833 - val_loss: 0.6243
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.6975 - loss: 0.6140 - val_accuracy: 0.6833 - val_loss: 0.6255
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.6854 - loss: 0.6235 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.6846 - loss: 0.6235 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.6944 - loss: 0.6157 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.6818 - loss: 0.6257 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.6840 - loss: 0.6238 - val_accuracy: 0.6833 - val_loss: 0.6249
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.6910 - loss: 0.6190 - val_accuracy: 0.6833 - val_loss: 0.6246
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6878 - loss: 0.6213 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6838 - loss: 0.6240 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6853 - loss: 0.6228 - val_accuracy: 0.6833 - val_loss: 0.6243
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6920 - loss: 0.6177 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6823 - loss: 0.6253 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.6792 - loss: 0.6277 - val_accuracy: 0.6833 - val_loss: 0.6247
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.6957 - loss: 0.6143 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6787 - loss: 0.6281 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6859 - loss: 0.6224 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6922 - loss: 0.6179 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.6826 - loss: 0.6253 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6832 - loss: 0.6246 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.6922 - loss: 0.6177 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.6876 - loss: 0.6215 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.6845 - loss: 0.6238 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6804 - loss: 0.6267 - val_accuracy: 0.6833 - val_loss: 0.6254
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6847 - loss: 0.6241 - val_accuracy: 0.6833 - val_loss: 0.6243
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6801 - loss: 0.6269 - val_accuracy: 0.6833 - val_loss: 0.6245
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.6866 - loss: 0.6217 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6888 - loss: 0.6202 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6819 - loss: 0.6254 - val_accuracy: 0.6833 - val_loss: 0.6241
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6764 - loss: 0.6296 - val_accuracy: 0.6833 - val_loss: 0.6243
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.6898 - loss: 0.6195 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6827 - loss: 0.6249 - val_accuracy: 0.6833 - val_loss: 0.6253
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.6826 - loss: 0.6259 - val_accuracy: 0.6833 - val_loss: 0.6244
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6907 - loss: 0.6186 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.6769 - loss: 0.6292 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6872 - loss: 0.6213 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6905 - loss: 0.6187 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6809 - loss: 0.6265 - val_accuracy: 0.6833 - val_loss: 0.6247
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6864 - loss: 0.6222 - val_accuracy: 0.6833 - val_loss: 0.6242
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6746 - loss: 0.6309 - val_accuracy: 0.6833 - val_loss: 0.6243
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6686 - loss: 0.6347 - val_accuracy: 0.6833 - val_loss: 0.6251
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.6851 - loss: 0.6236 - val_accuracy: 0.6833 - val_loss: 0.6240
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.6871 - loss: 0.6216 - val_accuracy: 0.6833 - val_loss: 0.6247
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6800 - loss: 0.6269 - val_accuracy: 0.6833 - val_loss: 0.6244

# %%
# Getting predictions in the form of probabilities
prediction_probabilities = model.predict(X_valid)
# Extracting the class with the highest probability for each prediction
predictions = prediction_probabilities.argmax(axis=-1)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
from sklearn.metrics import accuracy_score
print('Accuracy on validation set:', accuracy_score(y_valid, predictions), '%')
# Out:
# Accuracy on validation set: 0.31666666666666665 %
